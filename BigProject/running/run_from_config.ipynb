# %% [markdown]
# # Emotion Contagion ABM: Run from YAML
#
# This notebook runs the modularized simulation code using a YAML config file. Edit `default.yaml`, then run the cells below.

# %%
from pathlib import Path
from run_from_config import load_config, run_from_config

config_path = Path("default.yaml")
config = load_config(config_path)
batch = run_from_config(config)

print("n_results:", len(batch["results"]))
print("output_dir:", batch["output_dir"])
# Out:
# {'population_size': 15, 'max_iterations': 420, 'min_weight': 0.01, 'include_leader_ties': True, 'leader_to_member_cap': None, 'member_to_leader_cap': None, 'leader_to_member_value': None, 'member_to_leader_value': None, 'adaptive_intimacy': True, 'kappa': 0.08, 'decay': 0.01, 'min_w': 0.01, 'max_w': 1.0, 'dampening': 0.08, 'use_rl_leader': True, 'strength': 0.5, 'n_communities': 2, 'intra_strength': 0.5, 'inter_strength': 0.2, 'n_periphery': 3, 'core_to_periph': 0.5, 'periph_to_core': 0.2, 'periph_to_periph': 0.2, 'structure': 'random', 'leader_style': 'No_Intervention', 'condition_name': 'structure_random__leader_style_No_Intervention'}
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       4 config_path = Path("default.yaml")
#       5 config = load_config(config_path)
# ----> 6 batch = run_from_config(config)
#       8 print("n_results:", len(batch["results"]))
#       9 print("output_dir:", batch["output_dir"])
#
# File r:\sescott1\Masters\523\Emotion-Contagion\BigProject\running\run_from_config.py:178, in run_from_config(config)
#     176     fixed_params = grid_cfg.get("fixed_params", {})
#     177     condition_name_keys = grid_cfg.get("condition_name_keys")
# --> 178     batch = run_multiple_simulations(seeds=seeds, condition_grid=condition_grid, fixed_params=fixed_params, condition_name_keys=condition_name_keys, **output_kwargs,)
#     179 else:
#     180     raise ValueError(f"Unsupported mode {mode!r}. Choose from 'single', 'manual', or 'grid'.")
#
# File \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\running\run_multiple_simulations.py:541, in run_multiple_simulations(seeds, conditions, condition_grid, fixed_params, condition_name_keys, population_size, structure, leader_style, max_iterations, min_weight, include_leader_ties, leader_to_member_cap, member_to_leader_cap, leader_to_member_value, member_to_leader_value, strength, n_communities, intra_strength, inter_strength, n_periphery, core_to_periph, periph_to_core, periph_to_periph, adaptive_intimacy, kappa, decay, min_w, max_w, dampening, use_rl_leader, rl_alpha, rl_gamma, rl_epsilon_start, rl_epsilon_end, rl_epsilon_decay_steps, rl_actions, condition_name, output_root, output_subdir, create_subfolders, add_timestamp_to_output_dir, separate_condition_folders, separate_run_folders, save_full_results, save_run_metadata, save_summary, save_q_tables, summary_filename, results_filename_template, metadata_filename_template, qtable_filename_template)
#     538 global_run_counter += 1
#     539 run_id = global_run_counter
# --> 541 results = run_simulation(
#     542     seed=seed,
#     543     run_id=run_id,
#     544
#     545     population_size=condition["population_size"],
#     546     structure=condition["structure"],
#     547     leader_style=condition["leader_style"],
#     548     max_iterations=condition["max_iterations"],
#     549
#     550     min_weight=condition.get("min_weight", 0.01),
#     551     include_leader_ties=condition.get("include_leader_ties", True),
#     552     leader_to_member_cap=condition.get("leader_to_member_cap"),
#     553     member_to_leader_cap=condition.get( "member_to_leader_cap"),
#     554     leader_to_member_value=condition.get("leader_to_member_value"),
#     555     member_to_leader_value=condition.get("member_to_leader_value"),
#     556
#     557     strength=condition.get("strength"),
#     558
#     559     n_communities=condition.get("n_communities"),
#     560     intra_strength=condition.get("intra_strength"),
#     561     inter_strength=condition.get("inter_strength"),
#     562
#     563     n_periphery=condition.get("n_periphery"),
#     564     core_to_periph=condition.get("core_to_periph"),
#     565     periph_to_core=condition.get("periph_to_core"),
#     566     periph_to_periph=condition.get("periph_to_periph"),
#     567
#     568     adaptive_intimacy=condition.get("adaptive_intimacy", False),
#     569     kappa=condition.get("kappa"),
#     570     decay=condition.get("decay"),
#     571     min_w=condition.get("min_w"),
#     572     max_w=condition.get("max_w"),
#     573
#     574     dampening=condition.get("dampening", 0.08),
#     575
#     576     use_rl_leader=condition.get("use_rl_leader", False),
#     577     rl_alpha=condition.get("rl_alpha", 0.1),
#     578     rl_gamma=condition.get("rl_gamma", 0.95),
#     579     rl_epsilon_start=condition.get("rl_epsilon_start", 0.3),
#     580     rl_epsilon_end=condition.get("rl_epsilon_end", 0.05),
#     581     rl_epsilon_decay_steps=condition.get("rl_epsilon_decay_steps", 2000),
#     582     rl_actions=condition.get("rl_actions", [0, 1, 2, 3]),
#     583
#     584     condition_name=current_condition_name
#     585 )
#     587 all_results.append(results)
#     588 summary_rows.append(_results_to_summary_row(results=results, condition_name=current_condition_name, condition_index=condition_index))
#
# File \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\running\run_simulation.py:168, in run_simulation(seed, run_id, population_size, structure, leader_style, max_iterations, min_weight, include_leader_ties, leader_to_member_cap, member_to_leader_cap, leader_to_member_value, member_to_leader_value, strength, n_communities, intra_strength, inter_strength, n_periphery, core_to_periph, periph_to_core, periph_to_periph, adaptive_intimacy, kappa, decay, min_w, max_w, dampening, condition_name, use_rl_leader, rl_alpha, rl_gamma, rl_epsilon_start, rl_epsilon_end, rl_epsilon_decay_steps, **kwargs)
#     165 _validate_adaptive_params(adaptive_intimacy=adaptive_intimacy, kappa=kappa, decay=decay, min_w=min_w, max_w=max_w)
#     167 rng = np.random.default_rng(seed)
# --> 168 state = initialize_simulation(
#     169     rng=rng,
#     170     population_size=population_size,
#     171     structure=structure,
#     172     leader_style=leader_style,
#     173     min_weight=min_weight,
#     174     include_leader_ties=include_leader_ties,
#     175     leader_to_member_cap=leader_to_member_cap,
#     176     member_to_leader_cap=member_to_leader_cap,
#     177     leader_to_member_value=leader_to_member_value,
#     178     member_to_leader_value=member_to_leader_value,
#     179     strength=strength,
#     180     n_communities=n_communities,
#     181     intra_strength=intra_strength,
#     182     inter_strength=inter_strength,
#     183     n_periphery=n_periphery,
#     184     core_to_periph=core_to_periph,
#     185     periph_to_core=periph_to_core,
#     186     periph_to_periph=periph_to_periph,
#     187 )
#     189 behavior = leader_behaviors[leader_style]
#     190 if use_rl_leader and behavior["uses_rl"]:
#
# File \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\running\build_simulation.py:179, in initialize_simulation(rng, population_size, structure, leader_style, min_weight, include_leader_ties, leader_to_member_cap, member_to_leader_cap, leader_to_member_value, member_to_leader_value, strength, n_communities, intra_strength, inter_strength, n_periphery, core_to_periph, periph_to_core, periph_to_periph)
#     176 agents, leader_index = select_and_configure_leader(rng=rng, agents=agents, leader_style=leader_style)
#     177 agents = assign_indices_and_roles(agents=agents, leader_index=leader_index)
# --> 179 intimacy_matrix, assignments = build_initial_intimacy_matrix(
#     180     rng=rng,
#     181     population_size=population_size,
#     182     structure=structure,
#     183     leader_index=leader_index,
#     184     min_weight=min_weight,
#     185     include_leader_ties=include_leader_ties,
#     186     leader_to_member_cap=leader_to_member_cap,
#     187     member_to_leader_cap=member_to_leader_cap,
#     188     leader_to_member_value=leader_to_member_value,
#     189     member_to_leader_value=member_to_leader_value,
#     190     strength=strength,
#     191     n_communities=n_communities,
#     192     intra_strength=intra_strength,
#     193     inter_strength=inter_strength,
#     194     n_periphery=n_periphery,
#     195     core_to_periph=core_to_periph,
#     196     periph_to_core=periph_to_core,
#     197     periph_to_periph=periph_to_periph,
#     198 )
#     200 metadata = {
#     201     "population_size": population_size,
#     202     "structure": structure,
#    (...)    216     "periph_to_periph": periph_to_periph,
#     217 }
#     219 return SimulationState(agents=agents, leader_index=leader_index, intimacy_matrix=intimacy_matrix, assignments=assignments, time=0, metadata=metadata)
#
# File \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\running\build_simulation.py:84, in build_initial_intimacy_matrix(rng, population_size, structure, leader_index, min_weight, include_leader_ties, leader_to_member_cap, member_to_leader_cap, leader_to_member_value, member_to_leader_value, strength, n_communities, intra_strength, inter_strength, n_periphery, core_to_periph, periph_to_core, periph_to_periph)
#      60 def build_initial_intimacy_matrix(
#      61     rng: np.random.Generator,
#      62     population_size: int,
#    (...)     78     periph_to_periph: Optional[float] = None,
#      79 ) -> tuple[np.ndarray, np.ndarray]:
#      80     """
#      81     Build one unified intimacy matrix over all agents.
#      82     Base matrix generation is delegated to network.py, then optionally leader-related ties are overwritten to make leader-member ties distinct from member-member ties.
#      83     """
# ---> 84     intimacy_matrix, assignments = create_intimacy_matrix(
#      85         rng=rng,
#      86         population=population_size,
#      87         structure=structure,
#      88         min_weight=min_weight,
#      89         leader_index=leader_index,
#      90         strength=strength,
#      91         n_communities=n_communities,
#      92         intra_strength=intra_strength,
#      93         inter_strength=inter_strength,
#      94         n_periphery=n_periphery,
#      95         core_to_periph=core_to_periph,
#      96         periph_to_core=periph_to_core,
#      97         periph_to_periph=periph_to_periph,
#      98     )
#     100     if not include_leader_ties:
#     101         intimacy_matrix[leader_index, :] = 0.0
#
# File \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\src\network.py:250, in create_intimacy_matrix(rng, population, structure, min_weight, leader_index, strength, n_communities, intra_strength, inter_strength, n_periphery, core_to_periph, periph_to_core, periph_to_periph)
#     247 _validate_strength(periph_to_core, "periph_to_core")
#     248 _validate_strength(periph_to_periph, "periph_to_periph")
# --> 250 assignments = _core_periphery_assignments( population=population, leader_index=leader_index, n_periphery=n_periphery,)
#     252 for i in range(population):
#     253     for j in range(population):
#
# File \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\src\network.py:124, in _core_periphery_assignments(population, leader_index, n_periphery)
#     121     raise ValueError(f"Requested n_periphery={n_periphery}, but only {n_non_leader} non-leader agents are available. Reduce n_periphery or increase population.")
#     123 if n_periphery != n_non_leader:
# --> 124     raise ValueError(f"With the current design, the leader is the single core and all non-leader agents are peripheral, so n_periphery must equal {n_non_leader}. Received {n_periphery}.")
#     126 assignments = np.zeros(population, dtype=int)
#     127 assignments[leader_index] = 1
#
# ValueError: With the current design, the leader is the single core and all non-leader agents are peripheral, so n_periphery must equal 14. Received 3.

# %%
print(f"Completed {len(batch['results'])} runs.")
print(f"Outputs saved under: {batch['output_dir']}")
if batch.get('summary_path') is not None:
    print(f"Summary CSV: {batch['summary_path']}")
# Out:
# Completed 360 runs.
# Outputs saved under: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-06-02_14-17-31
# Summary CSV: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-06-02_14-17-31\summary.csv

# %%
summary_df = batch.get('summary_df')
summary_df
# Out:
#      condition_index condition_name  run_id  seed       structure  \
# 0                  1           None       1     0          random
# 1                  1           None       2     1          random
# 2                  1           None       3     2          random
# 3                  1           None       4     3          random
# 4                  1           None       5     4          random
# ..               ...            ...     ...   ...             ...
# 355               18           None     356    15  core_periphery
# 356               18           None     357    16  core_periphery
# 357               18           None     358    17  core_periphery
# 358               18           None     359    18  core_periphery
# 359               18           None     360    19  core_periphery
#
#         leader_style  population_size  max_iterations  adaptive_intimacy  \
# 0    No_Intervention               11             400               True
# 1    No_Intervention               11             400               True
# 2    No_Intervention               11             400               True
# 3    No_Intervention               11             400               True
# 4    No_Intervention               11             400               True
# ..               ...              ...             ...                ...
# 355             Free               11             400               True
# 356             Free               11             400               True
# 357             Free               11             400               True
# 358             Free               11             400               True
# 359             Free               11             400               True
#
#      use_rl_leader  num_interventions  final_avg_member_emotion  \
# 0             True                  0                 -0.712185
# 1             True                  0                 -0.135774
# 2             True                  0                 -0.817290
# 3             True                  0                 -0.483872
# 4             True                  0                 -0.002446
# ..             ...                ...                       ...
# 355           True                381                 -0.764754
# 356           True                369                 -0.724021
# 357           True                368                  0.152606
# 358           True                304                  0.068643
# 359           True                259                  0.096494
#
#      final_min_member_emotion  final_max_member_emotion  mean_rl_reward  \
# 0                   -1.000000                 -0.200747             NaN
# 1                   -0.414118                 -0.046677             NaN
# 2                   -1.000000                 -0.274858             NaN
# 3                   -1.000000                 -0.042604             NaN
# 4                   -0.004400                 -0.001020             NaN
# ..                        ...                       ...             ...
# 355                 -1.000000                 -0.091053       -0.001439
# 356                 -0.995775                 -0.174923       -0.001377
# 357                  0.059972                  0.217163        0.000973
# 358                  0.016943                  0.131776        0.000750
# 359                  0.061465                  0.137922        0.000763
#
#      mean_rl_quality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 355        -0.763606
# 356        -0.697352
# 357         0.011950
# 358         0.040716
# 359         0.003862
#
# [360 rows x 16 columns]

# %%
summary_df.shape
# Out:
# (360, 16)

# %%
first_result = batch['results'][0]
first_result.metadata
# Out:
# {'population_size': 11,
#  'structure': 'random',
#  'leader_style': 'No_Intervention',
#  'include_leader_ties': True,
#  'leader_to_member_cap': None,
#  'member_to_leader_cap': None,
#  'leader_to_member_value': None,
#  'member_to_leader_value': None,
#  'strength': 0.5,
#  'n_communities': 2,
#  'intra_strength': 0.5,
#  'inter_strength': 0.2,
#  'n_periphery': 10,
#  'core_to_periph': 0.5,
#  'periph_to_core': 0.2,
#  'periph_to_periph': 0.2,
#  'condition_name': None,
#  'max_iterations': 400,
#  'adaptive_intimacy': True,
#  'kappa': 0.08,
#  'decay': 0.01,
#  'min_w': 0.01,
#  'max_w': 1.0,
#  'use_rl_leader': True}
