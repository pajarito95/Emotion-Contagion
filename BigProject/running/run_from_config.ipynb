# %% [markdown]
# # Emotion Contagion ABM: Run from YAML
#
# This notebook runs the modularized simulation code using a YAML config file. Edit `default.yaml`, then run the cells below.

# %%
from pathlib import Path
from run_from_config import load_config, run_from_config

config_path = Path("default.yaml")
config = load_config(config_path)
batch = run_from_config(config)

print("n_results:", len(batch["results"]))
print("output_dir:", batch["output_dir"])
# Out:
# n_results: 180
# output_dir: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs_2026-05-25_14-42-23

# %%
print(f"Completed {len(batch['results'])} runs.")
print(f"Outputs saved under: {batch['output_dir']}")
if batch.get('summary_path') is not None:
    print(f"Summary CSV: {batch['summary_path']}")
# Out:
# Completed 180 runs.
# Outputs saved under: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs_2026-05-25_14-42-23
# Summary CSV: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs_2026-05-25_14-42-23\summary.csv

# %%
summary_df = batch.get('summary_df')
summary_df
# Out:
#      condition_index                                     condition_name  \
# 0                  1     structure_random__leader_style_No_Intervention
# 1                  1     structure_random__leader_style_No_Intervention
# 2                  1     structure_random__leader_style_No_Intervention
# 3                  1     structure_random__leader_style_No_Intervention
# 4                  1     structure_random__leader_style_No_Intervention
# ..               ...                                                ...
# 175                9  structure_core_periphery__leader_style_Low_Ini...
# 176                9  structure_core_periphery__leader_style_Low_Ini...
# 177                9  structure_core_periphery__leader_style_Low_Ini...
# 178                9  structure_core_periphery__leader_style_Low_Ini...
# 179                9  structure_core_periphery__leader_style_Low_Ini...
#
#      run_id  seed  n_agents  leader_index               leader_style  \
# 0         1     0        11             9            No_Intervention
# 1         2     1        11             0            No_Intervention
# 2         3     2        11             5            No_Intervention
# 3         4     3        11            10            No_Intervention
# 4         5     4        11             9            No_Intervention
# ..      ...   ...       ...           ...                        ...
# 175     176    15        11             1  Low_Initially_Constrained
# 176     177    16        11             2  Low_Initially_Constrained
# 177     178    17        11             5  Low_Initially_Constrained
# 178     179    18        11            10  Low_Initially_Constrained
# 179     180    19        11             4  Low_Initially_Constrained
#
#           structure  max_iterations  adaptive_intimacy  num_interventions  \
# 0            random              50              False                  0
# 1            random              50              False                  0
# 2            random              50              False                  0
# 3            random              50              False                  0
# 4            random              50              False                  0
# ..              ...             ...                ...                ...
# 175  core_periphery              50              False                 14
# 176  core_periphery              50              False                  2
# 177  core_periphery              50              False                  0
# 178  core_periphery              50              False                  0
# 179  core_periphery              50              False                  0
#
#                                 intervention_timesteps  total_interactions  \
# 0                                                   []                 309
# 1                                                   []                 275
# 2                                                   []                 303
# 3                                                   []                 329
# 4                                                   []                 292
# ..                                                 ...                 ...
# 175  [35, 36, 38, 39, 40, 41, 42, 43, 44, 45, 46, 4...                 277
# 176                                           [48, 49]                 278
# 177                                                 []                 283
# 178                                                 []                 324
# 179                                                 []                 283
#
#      mean_interactions_per_timestep  final_avg_member_emotion  \
# 0                              6.18                 -0.515365
# 1                              5.50                 -0.213751
# 2                              6.06                 -0.756596
# 3                              6.58                 -0.427147
# 4                              5.84                 -0.139535
# ..                              ...                       ...
# 175                            5.54                 -0.723222
# 176                            5.56                 -0.707132
# 177                            5.66                 -0.233331
# 178                            6.48                 -0.015356
# 179                            5.66                 -0.086860
#
#      final_min_member_emotion  final_max_member_emotion  leader_emotion  \
# 0                   -1.000000                 -0.212436             1.0
# 1                   -0.401696                 -0.073193             1.0
# 2                   -1.000000                 -0.292664             1.0
# 3                   -1.000000                 -0.083015             1.0
# 4                   -0.281801                 -0.050385             1.0
# ..                        ...                       ...             ...
# 175                 -0.997414                 -0.096247             1.0
# 176                 -0.995775                 -0.224999             1.0
# 177                 -0.377302                 -0.058151             1.0
# 178                 -0.031399                 -0.001086             1.0
# 179                 -0.212631                 -0.042593             1.0
#
#      leader_threshold leader_emotion_management_ability
# 0                 NaN                              None
# 1                 NaN                              None
# 2                 NaN                              None
# 3                 NaN                              None
# 4                 NaN                              None
# ..                ...                               ...
# 175              -0.7                               Low
# 176              -0.7                               Low
# 177              -0.7                               Low
# 178              -0.7                               Low
# 179              -0.7                               Low
#
# [180 rows x 20 columns]

# %%
summary_df.shape
# Out:
# (180, 20)

# %%
first_result = batch['results'][0]
first_result.metadata
# Out:
# {'population_size': 11,
#  'structure': 'random',
#  'leader_style': 'No_Intervention',
#  'include_leader_ties': True,
#  'leader_to_member_cap': None,
#  'member_to_leader_cap': None,
#  'leader_to_member_value': None,
#  'member_to_leader_value': None,
#  'strength': 0.5,
#  'n_communities': 2,
#  'intra_strength': 0.5,
#  'inter_strength': 0.2,
#  'n_periphery': 10,
#  'core_to_periph': 0.5,
#  'periph_to_core': 0.2,
#  'periph_to_periph': 0.2,
#  'condition_name': 'structure_random__leader_style_No_Intervention',
#  'max_iterations': 50,
#  'adaptive_intimacy': False,
#  'kappa': None,
#  'decay': None,
#  'min_w': None,
#  'max_w': None}
