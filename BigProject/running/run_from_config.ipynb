# %% [markdown]
# # Emotion Contagion ABM: Run from YAML
#
# This notebook runs the modularized simulation code using a YAML config file. Edit `default.yaml`, then run the cells below.

# %%
from pathlib import Path
from run_from_config import load_config, run_from_config

config_path = Path("default.yaml")
config = load_config(config_path)
batch = run_from_config(config)

print("n_results:", len(batch["results"]))
print("output_dir:", batch["output_dir"])
# Out:
# {'population_size': 11, 'max_iterations': 235, 'min_weight': 0.01, 'include_leader_ties': True, 'leader_to_member_cap': None, 'member_to_leader_cap': None, 'leader_to_member_value': None, 'member_to_leader_value': None, 'adaptive_intimacy': True, 'kappa': 0.08, 'decay': 0.01, 'min_w': 0.01, 'max_w': 1.0, 'dampening': 0.08, 'use_rl_leader': True, 'strength': 0.5, 'n_communities': 2, 'intra_strength': 0.5, 'inter_strength': 0.2, 'n_periphery': 10, 'core_to_periph': 0.5, 'periph_to_core': 0.2, 'periph_to_periph': 0.2, 'structure': 'random', 'leader_style': 'No_Intervention', 'condition_name': 'structure_random__leader_style_No_Intervention'}
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# n_results: 360
# output_dir: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-06-01_15-23-26

# %%
print(f"Completed {len(batch['results'])} runs.")
print(f"Outputs saved under: {batch['output_dir']}")
if batch.get('summary_path') is not None:
    print(f"Summary CSV: {batch['summary_path']}")
# Out:
# Completed 360 runs.
# Outputs saved under: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-06-01_15-23-26
# Summary CSV: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-06-01_15-23-26\summary.csv

# %%
summary_df = batch.get('summary_df')
summary_df
# Out:
#      condition_index condition_name  run_id  seed       structure  \
# 0                  1           None       1     0          random
# 1                  1           None       2     1          random
# 2                  1           None       3     2          random
# 3                  1           None       4     3          random
# 4                  1           None       5     4          random
# ..               ...            ...     ...   ...             ...
# 355               18           None     356    15  core_periphery
# 356               18           None     357    16  core_periphery
# 357               18           None     358    17  core_periphery
# 358               18           None     359    18  core_periphery
# 359               18           None     360    19  core_periphery
#
#         leader_style  population_size  max_iterations  adaptive_intimacy  \
# 0    No_Intervention               11             235               True
# 1    No_Intervention               11             235               True
# 2    No_Intervention               11             235               True
# 3    No_Intervention               11             235               True
# 4    No_Intervention               11             235               True
# ..               ...              ...             ...                ...
# 355             Free               11             235               True
# 356             Free               11             235               True
# 357             Free               11             235               True
# 358             Free               11             235               True
# 359             Free               11             235               True
#
#      use_rl_leader  num_interventions  final_avg_member_emotion  \
# 0             True                  0                 -0.712204
# 1             True                  0                 -0.182437
# 2             True                  0                 -0.794950
# 3             True                  0                 -0.468902
# 4             True                  0                 -0.017020
# ..             ...                ...                       ...
# 355           True                222                 -0.747107
# 356           True                216                 -0.713618
# 357           True                214                  0.064227
# 358           True                146                  0.061914
# 359           True                106                  0.040806
#
#      final_min_member_emotion  final_max_member_emotion  mean_rl_reward  \
# 0                   -1.000000                 -0.200753             NaN
# 1                   -0.571011                 -0.059856             NaN
# 2                   -1.000000                 -0.264227             NaN
# 3                   -1.000000                 -0.050194             NaN
# 4                   -0.029653                 -0.006694             NaN
# ..                        ...                       ...             ...
# 355                 -0.997414                 -0.087215       -0.002351
# 356                 -0.997886                 -0.159781       -0.002309
# 357                  0.024722                  0.104828        0.001294
# 358                  0.015291                  0.128125        0.001249
# 359                  0.004609                  0.071899        0.001063
#
#      mean_rl_quality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 355        -0.740743
# 356        -0.660456
# 357        -0.065754
# 358         0.020780
# 359        -0.044955
#
# [360 rows x 16 columns]

# %%
summary_df.shape
# Out:
# (360, 16)

# %%
first_result = batch['results'][0]
first_result.metadata
# Out:
# {'population_size': 11,
#  'structure': 'random',
#  'leader_style': 'No_Intervention',
#  'include_leader_ties': True,
#  'leader_to_member_cap': None,
#  'member_to_leader_cap': None,
#  'leader_to_member_value': None,
#  'member_to_leader_value': None,
#  'strength': 0.5,
#  'n_communities': 2,
#  'intra_strength': 0.5,
#  'inter_strength': 0.2,
#  'n_periphery': 10,
#  'core_to_periph': 0.5,
#  'periph_to_core': 0.2,
#  'periph_to_periph': 0.2,
#  'condition_name': None,
#  'max_iterations': 235,
#  'adaptive_intimacy': True,
#  'kappa': 0.08,
#  'decay': 0.01,
#  'min_w': 0.01,
#  'max_w': 1.0,
#  'use_rl_leader': True}
