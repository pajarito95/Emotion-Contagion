# %% [markdown]
# # Emotion Contagion ABM: Run from YAML
#
# This notebook runs the modularized simulation code using a YAML config file. Edit `default.yaml`, then run the cells below.

# %%
from pathlib import Path
from run_from_config import load_config, run_from_config

config_path = Path("default.yaml")
config = load_config(config_path)
batch = run_from_config(config)

print("n_results:", len(batch["results"]))
print("output_dir:", batch["output_dir"])
# Out:
# n_results: 360
# output_dir: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-05-28_12-05-23

# %%
print(f"Completed {len(batch['results'])} runs.")
print(f"Outputs saved under: {batch['output_dir']}")
if batch.get('summary_path') is not None:
    print(f"Summary CSV: {batch['summary_path']}")
# Out:
# Completed 360 runs.
# Outputs saved under: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-05-28_12-05-23
# Summary CSV: \\lightning.bu.binghamton.edu\WISE\sescott1\Masters\523\Emotion-Contagion\BigProject\outputs\2026-05-28_12-05-23\summary.csv

# %%
summary_df = batch.get('summary_df')
summary_df
# Out:
#      condition_index                                  condition_name  run_id  \
# 0                  1  structure_random__leader_style_No_Intervention       1
# 1                  1  structure_random__leader_style_No_Intervention       2
# 2                  1  structure_random__leader_style_No_Intervention       3
# 3                  1  structure_random__leader_style_No_Intervention       4
# 4                  1  structure_random__leader_style_No_Intervention       5
# ..               ...                                             ...     ...
# 355               18     structure_core_periphery__leader_style_Free     356
# 356               18     structure_core_periphery__leader_style_Free     357
# 357               18     structure_core_periphery__leader_style_Free     358
# 358               18     structure_core_periphery__leader_style_Free     359
# 359               18     structure_core_periphery__leader_style_Free     360
#
#      seed       structure     leader_style  population_size  max_iterations  \
# 0       0          random  No_Intervention               11             235
# 1       1          random  No_Intervention               11             235
# 2       2          random  No_Intervention               11             235
# 3       3          random  No_Intervention               11             235
# 4       4          random  No_Intervention               11             235
# ..    ...             ...              ...              ...             ...
# 355    15  core_periphery             Free               11             235
# 356    16  core_periphery             Free               11             235
# 357    17  core_periphery             Free               11             235
# 358    18  core_periphery             Free               11             235
# 359    19  core_periphery             Free               11             235
#
#      adaptive_intimacy  use_rl_leader  num_interventions  \
# 0                 True          False                  0
# 1                 True          False                  0
# 2                 True          False                  0
# 3                 True          False                  0
# 4                 True          False                  0
# ..                 ...            ...                ...
# 355               True          False                235
# 356               True          False                235
# 357               True          False                235
# 358               True          False                235
# 359               True          False                235
#
#      final_avg_member_emotion  final_min_member_emotion  \
# 0                   -0.712204                 -1.000000
# 1                   -0.182437                 -0.571011
# 2                   -0.794950                 -1.000000
# 3                   -0.468902                 -1.000000
# 4                   -0.017020                 -0.029653
# ..                        ...                       ...
# 355                 -0.751253                 -0.997414
# 356                 -0.703731                 -0.997886
# 357                  0.147296                  0.056207
# 358                  0.075080                  0.013278
# 359                  0.088515                  0.059657
#
#      final_max_member_emotion mean_rl_reward mean_rl_quality
# 0                   -0.200753           None            None
# 1                   -0.059856           None            None
# 2                   -0.264227           None            None
# 3                   -0.050194           None            None
# 4                   -0.006694           None            None
# ..                        ...            ...             ...
# 355                 -0.087756           None            None
# 356                 -0.159355           None            None
# 357                  0.209856           None            None
# 358                  0.137087           None            None
# 359                  0.135842           None            None
#
# [360 rows x 16 columns]

# %%
summary_df.shape
# Out:
# (360, 16)

# %%
first_result = batch['results'][0]
first_result.metadata
# Out:
# {'population_size': 11,
#  'structure': 'random',
#  'leader_style': 'No_Intervention',
#  'include_leader_ties': True,
#  'leader_to_member_cap': None,
#  'member_to_leader_cap': None,
#  'leader_to_member_value': None,
#  'member_to_leader_value': None,
#  'strength': 0.5,
#  'n_communities': 2,
#  'intra_strength': 0.5,
#  'inter_strength': 0.2,
#  'n_periphery': 10,
#  'core_to_periph': 0.5,
#  'periph_to_core': 0.2,
#  'periph_to_periph': 0.2,
#  'condition_name': 'structure_random__leader_style_No_Intervention',
#  'max_iterations': 235,
#  'adaptive_intimacy': True,
#  'kappa': 0.08,
#  'decay': 0.01,
#  'min_w': 0.01,
#  'max_w': 1.0,
#  'use_rl_leader': False}
