# %% [markdown]
# # Emotion Contagion ABM: Run from YAML
#
# This notebook runs the modularized simulation code using a YAML config file. Edit `default.yaml`, then run the cells below.

# %%
from pathlib import Path
from run_from_config import load_config, run_from_config

config = load_config(Path("default.yaml"))
batch = run_from_config(config)

print("n_results:", len(batch["results"]))
print("output_dir:", batch["output_dir"])
# Out:
# {'population_size': 10, 'max_iterations': 15, 'susceptibility': 0.5, 'expressiveness': 0.5, 'amplification': 0.5, 'bias': 0.5, 'directed': False, 'min_weight': 0.01, 'include_leader_ties': True, 'leader_to_member_cap': None, 'member_to_leader_cap': None, 'leader_to_member_value': None, 'member_to_leader_value': None, 'adaptive_intimacy': False, 'kappa': 0.08, 'decay': 0.01, 'min_w': 0.01, 'max_w': 1.0, 'dampening': 0.08, 'use_rl_leader': True, 'strength': 0.5, 'n_communities': 4, 'intra_strength': 0.5, 'inter_strength': 0.2, 'core_proportion': 0.25, 'core_to_core': 0.65, 'core_to_periph': 0.5, 'periph_to_core': 0.2, 'periph_to_periph': 0.1, 'structure': 'random', 'leader_style': 'No_Intervention', 'condition_name': 'structure_random__leader_style_No_Intervention'}
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# Running structure=random, leader=No_Intervention, seed=0
# Running structure=random, leader=High_Fully_Constrained, seed=0
# Running structure=random, leader=Low_Fully_Constrained, seed=0
# Running structure=random, leader=High_Initially_Constrained, seed=0
# Running structure=random, leader=Low_Initially_Constrained, seed=0
# Running structure=random, leader=Free, seed=0
# Running structure=community, leader=No_Intervention, seed=0
# Running structure=community, leader=High_Fully_Constrained, seed=0
# Running structure=community, leader=Low_Fully_Constrained, seed=0
# Running structure=community, leader=High_Initially_Constrained, seed=0
# Running structure=community, leader=Low_Initially_Constrained, seed=0
# Running structure=community, leader=Free, seed=0
# Running structure=core_periphery, leader=No_Intervention, seed=0
# Running structure=core_periphery, leader=High_Fully_Constrained, seed=0
# Running structure=core_periphery, leader=Low_Fully_Constrained, seed=0
# Running structure=core_periphery, leader=High_Initially_Constrained, seed=0
# Running structure=core_periphery, leader=Low_Initially_Constrained, seed=0
# Running structure=core_periphery, leader=Free, seed=0
# n_results: 18
# output_dir: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs\2026-08-06_13-44-29

# %%
print(f"Completed {len(batch['results'])} runs.")
print(f"Outputs saved under: {batch['output_dir']}")
if batch.get('summary_path') is not None:
    print(f"Summary CSV: {batch['summary_path']}")
# Out:
# Completed 18 runs.
# Outputs saved under: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs\2026-08-06_13-44-29
# Summary CSV: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs\2026-08-06_13-44-29\summary.csv

# %%
summary_df = batch.get('summary_df')
summary_df
# Out:
#      condition_index condition_name  run_id  seed       structure  \
# 0                  1           None       1     0          random
# 1                  1           None       2     1          random
# 2                  1           None       3     2          random
# 3                  1           None       4     3          random
# 4                  1           None       5     4          random
# ..               ...            ...     ...   ...             ...
# 229               18           None     230     8  core_periphery
# 230               18           None     231     9  core_periphery
# 231               18           None     232    10  core_periphery
# 232               18           None     233    11  core_periphery
# 233               18           None     234    12  core_periphery
#
#         leader_style  population_size  max_iterations  adaptive_intimacy  \
# 0    No_Intervention               90             420               True
# 1    No_Intervention               90             420               True
# 2    No_Intervention               90             420               True
# 3    No_Intervention               90             420               True
# 4    No_Intervention               90             420               True
# ..               ...              ...             ...                ...
# 229             Free               90             420               True
# 230             Free               90             420               True
# 231             Free               90             420               True
# 232             Free               90             420               True
# 233             Free               90             420               True
#
#      use_rl_leader  num_interventions  final_avg_member_emotion  \
# 0             True                  0                 -0.801348
# 1             True                  0                 -0.629358
# 2             True                  0                 -0.631525
# 3             True                  0                 -0.649130
# 4             True                  0                 -0.649445
# ..             ...                ...                       ...
# 229           True                333                  0.845232
# 230           True                348                  0.818606
# 231           True                376                  0.539674
# 232           True                382                  0.935048
# 233           True                305                  0.779761
#
#      final_min_member_emotion  final_max_member_emotion  mean_rl_reward  \
# 0                   -1.000000                 -0.079786             NaN
# 1                   -1.000000                 -0.005043             NaN
# 2                   -1.000000                 -0.050306             NaN
# 3                   -1.000000                 -0.067859             NaN
# 4                   -1.000000                 -0.022332             NaN
# ..                        ...                       ...             ...
# 229                 -0.127793                  0.971912        0.002590
# 230                  0.289318                  0.995466        0.002493
# 231                 -0.921952                  0.836973        0.001723
# 232                  0.780434                  0.994157        0.002779
# 233                  0.392244                  0.952199        0.002400
#
#      mean_rl_quality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 229         0.601743
# 230         0.613622
# 231         0.361533
# 232         0.662158
# 233         0.552020
#
# [234 rows x 16 columns]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
summary_df.shape
# Out:
# (234, 16)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
first_result = batch['results'][0]
first_result.metadata
# Out:
# {'population_size': 90,
#  'structure': 'random',
#  'leader_style': 'No_Intervention',
#  'leader_index': 89,
#  'include_leader_ties': True,
#  'strength': 0.5,
#  'n_communities': 4,
#  'intra_strength': 0.5,
#  'inter_strength': 0.2,
#  'core_proportion': 0.25,
#  'core_to_core': 0.65,
#  'core_to_periph': 0.5,
#  'periph_to_core': 0.2,
#  'periph_to_periph': 0.1,
#  'condition_name': None,
#  'max_iterations': 420,
#  'adaptive_intimacy': True,
#  'kappa': 0.08,
#  'decay': 0.01,
#  'min_w': 0.01,
#  'max_w': 1.0,
#  'use_rl_leader': True}
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
