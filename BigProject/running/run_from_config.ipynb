# %% [markdown]
# # Emotion Contagion ABM: Run from YAML
#
# This notebook runs the modularized simulation code using a YAML config file. Edit `default.yaml`, then run the cells below.

# %%
from pathlib import Path
from run_from_config import load_config, run_from_config

config_path = Path("default.yaml")
config = load_config(config_path)
batch = run_from_config(config)

print("n_results:", len(batch["results"]))
print("output_dir:", batch["output_dir"])
# Out:
# {'population_size': 90, 'max_iterations': 420, 'min_weight': 0.01, 'include_leader_ties': True, 'leader_to_member_cap': None, 'member_to_leader_cap': None, 'leader_to_member_value': None, 'member_to_leader_value': None, 'adaptive_intimacy': True, 'kappa': 0.08, 'decay': 0.01, 'min_w': 0.01, 'max_w': 1.0, 'dampening': 0.08, 'use_rl_leader': True, 'strength': 0.5, 'n_communities': 4, 'intra_strength': 0.5, 'inter_strength': 0.2, 'core_proportion': 0.25, 'core_to_core': 0.65, 'core_to_periph': 0.5, 'periph_to_core': 0.2, 'periph_to_periph': 0.1, 'structure': 'random', 'leader_style': 'No_Intervention', 'condition_name': 'structure_random__leader_style_No_Intervention'}
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True
# No_Intervention True
# High_Fully_Constrained True
# Low_Fully_Constrained True
# High_Initially_Constrained True
# Low_Initially_Constrained True
# Free True

# %%
print(f"Completed {len(batch['results'])} runs.")
print(f"Outputs saved under: {batch['output_dir']}")
if batch.get('summary_path') is not None:
    print(f"Summary CSV: {batch['summary_path']}")
# Out:
# Completed 234 runs.
# Outputs saved under: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs\2026-06-05_13-10-55
# Summary CSV: C:\Users\sarah\Downloads\Emotion-Contagion\BigProject\outputs\2026-06-05_13-10-55\summary.csv

# %%
summary_df = batch.get('summary_df')
summary_df
# Out:
#      condition_index condition_name  run_id  seed       structure  \
# 0                  1           None       1     0          random
# 1                  1           None       2     1          random
# 2                  1           None       3     2          random
# 3                  1           None       4     3          random
# 4                  1           None       5     4          random
# ..               ...            ...     ...   ...             ...
# 229               18           None     230     8  core_periphery
# 230               18           None     231     9  core_periphery
# 231               18           None     232    10  core_periphery
# 232               18           None     233    11  core_periphery
# 233               18           None     234    12  core_periphery
#
#         leader_style  population_size  max_iterations  adaptive_intimacy  \
# 0    No_Intervention               15             420               True
# 1    No_Intervention               15             420               True
# 2    No_Intervention               15             420               True
# 3    No_Intervention               15             420               True
# 4    No_Intervention               15             420               True
# ..               ...              ...             ...                ...
# 229             Free               15             420               True
# 230             Free               15             420               True
# 231             Free               15             420               True
# 232             Free               15             420               True
# 233             Free               15             420               True
#
#      use_rl_leader  num_interventions  final_avg_member_emotion  \
# 0             True                  0                 -0.807873
# 1             True                  0                 -0.467178
# 2             True                  0                 -0.654171
# 3             True                  0                 -0.541116
# 4             True                  0                 -0.620991
# ..             ...                ...                       ...
# 229           True                382                  0.992644
# 230           True                384                 -0.354788
# 231           True                377                  0.997602
# 232           True                367                  0.695767
# 233           True                381                  0.998982
#
#      final_min_member_emotion  final_max_member_emotion  mean_rl_reward  \
# 0                   -1.000000                 -0.212626             NaN
# 1                   -1.000000                 -0.091515             NaN
# 2                   -1.000000                 -0.172960             NaN
# 3                   -1.000000                 -0.061023             NaN
# 4                   -1.000000                 -0.138090             NaN
# ..                        ...                       ...             ...
# 229                  0.988801                  0.997227        0.003031
# 230                 -0.911483                  0.054567       -0.000262
# 231                  0.995300                  0.999418        0.002733
# 232                  0.554137                  0.874061        0.002247
# 233                  0.997970                  0.999795        0.002945
#
#      mean_rl_quality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 229         0.770468
# 230        -0.315555
# 231         0.820165
# 232         0.443447
# 233         0.820927
#
# [234 rows x 16 columns]

# %%
summary_df.shape
# Out:
# (234, 16)

# %%
first_result = batch['results'][0]
first_result.metadata
# Out:
# {'population_size': 15,
#  'structure': 'random',
#  'leader_style': 'No_Intervention',
#  'leader_index': 14,
#  'include_leader_ties': True,
#  'strength': 0.5,
#  'n_communities': 2,
#  'intra_strength': 0.5,
#  'inter_strength': 0.2,
#  'core_proportion': 0.25,
#  'core_to_core': 0.65,
#  'core_to_periph': 0.5,
#  'periph_to_core': 0.2,
#  'periph_to_periph': 0.1,
#  'condition_name': None,
#  'max_iterations': 420,
#  'adaptive_intimacy': True,
#  'kappa': 0.08,
#  'decay': 0.01,
#  'min_w': 0.01,
#  'max_w': 1.0,
#  'use_rl_leader': True}
